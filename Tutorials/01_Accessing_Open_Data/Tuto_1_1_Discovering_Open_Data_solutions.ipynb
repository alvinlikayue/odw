# %% [markdown]
# <span style="float: left;padding: 1.3em">![logo](../logo.png)</span>
#
# # Gravitational Wave Open Data Workshop
#
# ## Tutorial 1.1: Discovering open data from GW observatories
#
# This notebook describes how to discover what data are available from the [Gravitational-Wave Open Science Center (GWOSC)](https://gwosc.org).
#
# View this tutorial on [Google Colaboratory](https://colab.research.google.com/github/gw-odw/odw/blob/main/Tutorials/01_Accessing_Open_Data/Tuto_1.1_Discovering_Open_Data.ipynb) or launch [mybinder](https://mybinder.org/v2/gh/gw-odw/odw/HEAD).

# %% [markdown]
# ## Installation (execute only if running on a cloud platform, like Google Colab, or if you haven't done the installation already!)
#
# First, we need to install the software, which we do following the instruction in [Software Setup Instructions](../../setup.md):

# %% [markdown]
# > ⚠️ **Warning**: restart the runtime after running the cell below.
# >
# > To do so, click "Runtime" in the menu and choose "Restart and run all".
# >
# > You may see error messages but installation usually works.
# > If you experience problems, please [report an issue](https://github.com/gw-odw/odw/issues).

# %%
# -- Uncomment following line if running in Google Colab
! pip install -q 'gwosc==0.8.1'

# %% [markdown]
# ## Initialization

# %%
#check the version of the package gwosc you are using
import gwosc
print(gwosc.__version__)
# Out:
# 0.8.1

# %% [markdown]
# The version you get should be 0.8.1. If it's not, check that you have followed all the steps in [Software Setup Instructions](../../setup.md).

# %% [markdown]
# ## A brief presentation of GWOSC and Open Data

# %% [markdown]
# Open Science is the movement to make scientific research accessible to everyone and to increase scientific collaboration. Open Science includes different movements and practices such as open data, open source software and infrastructures, open access to publications and citizen science and more. See the [wikipedia page](https://en.wikipedia.org/wiki/Open_science) for more information.

# %% [markdown]
# Data from the LIGO-Virgo-KAGRA (LVK) collaboration are made available to the public via the [Gravitational-Wave Open Science Center (GWOSC)](https://gwosc.org), as described in the [LIGO Data Management Plan](https://dcc.ligo.org/LIGO-M1000066/public).

# %% [markdown]
# For a more detailed presentation of the data, including conventions on file and channel names and details about the preparation of the data, see the paper "Open Data from LIGO, Virgo, and KAGRA through the First Part of the Fourth Observing Run" ([link](https://arxiv.org/abs/2508.18079)).

# %% [markdown]
# The GWOSC also provides links to software used to analyze LVK data and organize training sessions (you are participating in it!).

# %% [markdown]
# ## Querying for event information
#
# The module `gwosc.datasets` provides tools for searching for datasets, including events, catalogs and full run strain data releases.
#
#
# For example, we can search for events in the [GWTC-1 catalog](https://gwosc.org/eventapi/html/GWTC-1-confident/), the catalog of all events from the O1 and O2 observing runs. A list of available catalogs can be seen in the [Event Portal](https://gwosc.org/eventapi)

# %%
from gwosc.datasets import find_datasets
from gwosc import datasets

#-- List all available catalogs
print("List of available catalogs")
print(find_datasets(type="catalog"))
# Out:
# List of available catalogs
# ['GWTC', 'GWTC-1-confident', 'GWTC-1-marginal', 'GWTC-2', 'GWTC-2.1-auxiliary', 'GWTC-2.1-confident', 'GWTC-2.1-marginal', 'GWTC-3-confident', 'GWTC-3-marginal', 'GWTC-4.0', 'IAS-O3a', 'Initial_LIGO_Virgo', 'O1_O2-Preliminary', 'O3_Discovery_Papers', 'O3_IMBH_marginal', 'O4_Discovery_Papers']

# %%
#-- Print all the GW events from the GWTC-1 catalog
gwtc1 = datasets.find_datasets(type='events', catalog='GWTC-1-confident')
print('GWTC-1 events:', gwtc1)
print("")
# Out:
# GWTC-1 events: ['GW150914-v3', 'GW151012-v3', 'GW151226-v2', 'GW170104-v2', 'GW170608-v3', 'GW170729-v1', 'GW170809-v1', 'GW170814-v3', 'GW170817-v3', 'GW170818-v1', 'GW170823-v1']

# %% [markdown]
# Note that the event name is of the type _GWyymmdd-vx_ where _x_ is the last available version for the data set provided by GWOSC.

# %%
#-- Print all the large strain data sets from LIGO/Virgo/KAGRA observing runs
runs = find_datasets(type='run')
print('Large data sets:', runs)
# Out:
# Large data sets: ['O1', 'O2', 'O3GK', 'O3a', 'O3b', 'O4a', 'O4b1Disc', 'O4b2Disc', 'O4b3Disc', 'S5', 'S6']

# %% [markdown]
# _Attention: Observing runs whose names end with "Disc" are not real runs but only structures we add in our database for technical reasons and are associated with GW candidate detections published before the data release of the associated observing run. The papers about these detections are called in our jargon "discovery papers", hence the "Disc" suffix (e.g. O4b1Disc -> GW241011)_

# %% [markdown]
# `datasets.find_datasets` also accepts a `segment` and `detector` keyword to narrow results based on GPS time and detector:

# %%
#-- Detector and segments keywords limit search result
print(datasets.find_datasets(type='events', catalog='GWTC-1-confident', detector="L1", segment=(1164556817, 1187733618)))
# Out:
# ['GW170104-v2', 'GW170608-v3', 'GW170729-v1', 'GW170809-v1', 'GW170814-v3', 'GW170817-v3', 'GW170818-v1', 'GW170823-v1']

# %% [markdown]
# Using `gwosc.datasets.event_gps`, we can query for the GPS time of a specific event (it works also without the version number):

# %%
from gwosc.datasets import event_gps
gps = event_gps('GW190425')
print(gps)
# Out:
# 1240215503.0

# %% [markdown]
# <div class="alert alert-info">All of these times are returned in the GPS time system, which counts the number of seconds that have elapsed since the start of the GPS epoch at midnight (00:00) on January 6th 1980. GWOSC provides a <a href="https://gwosc.org/gps/">GPS time converter</a> you can use to translate into datetime, or you can use <a href="https://gwpy.readthedocs.io/en/v3.0.14/time/"><code>gwpy.time</code></a>.</div>

# %%
# You can do also the vice-versa
from gwosc.datasets import event_at_gps
print(datasets.event_at_gps(1240215503))
# Out:
# GW190425

# %% [markdown]
# Note that the method `event_at_gps` looks for events found within 1 seconds of the given GPS time. If no events is found it will give an error.

# %% [markdown]
# We can query for the GPS time interval for an observing run:

# %%
from gwosc.datasets import run_segment
print(run_segment('O1'))
# Out:
# (1126051217, 1137254417)

# %%
# and vice-versa also in this case
from gwosc.datasets import run_at_gps
print(run_at_gps(1240215503))
# Out:
# O3a

# %% [markdown]
# Now we can use what we have learned with `run_segment` and `find_datasets` to see only the confident events in O1:

# %%
O1_events = datasets.find_datasets(type='events', catalog='GWTC-1-confident', segment=run_segment('O1'))
print(O1_events)
# Out:
# ['GW150914-v3', 'GW151012-v3', 'GW151226-v2']

# %% [markdown]
# ## Querying for data files
#
# The `gwosc.locate` module provides a function to find the URLs of data files associated with a given dataset.
#
# For event datasets, one can get the list of URLs using only the event name:

# %%
from gwosc.locate import get_event_urls
urls = get_event_urls('GW150914')
print(urls)
# Out:
# ['https://gwosc.org/archive/data/O1/1126170624/H-H1_LOSC_4_V1-1126256640-4096.hdf5', 'https://gwosc.org/archive/data/O1/1126170624/L-L1_LOSC_4_V1-1126256640-4096.hdf5']

# %% [markdown]
# By default, this function returns all of the files associated with a given event, which isn't particularly helpful. However, we can filter on any of these by using keyword arguments, for example to get the URL for the 32-second file for the LIGO-Livingston detector:

# %%
urls = get_event_urls('GW150914', duration=32, detector='L1')
print(urls)
# Out:
# ['https://gwosc.org/archive/data/O1/1126170624/L-L1_LOSC_4_V1-1126256640-4096.hdf5']

# %% [markdown]
# The different interferometers are denoted by a short identifier:
#
# - `'G1'` - GEO600
# - `'H1'` - LIGO-Hanford
# - `'L1'` - LIGO-Livingston
# - `'V1'` - (Advanced) Virgo
# - `'K1'` - KAGRA

# %% [markdown]
# ##  Query filtered by merger parameters
# The `query_events` module of `gwosc.datasets` allows to get a list of events filtered by some parameters, similar to what is done by the `Query` function of the [event portal](https://gwosc.org/eventapi/html/query/). A list of available parameters can be found [here](https://gwosc.readthedocs.io/en/stable/reference/gwosc.datasets.query_events.html) or using `query_events?`.
#
# Let's see how to use this module to find which events have been detected with a network signal to noise ratio (SNR) between 25 and 30:

# %%
from gwosc.datasets import query_events
selection = query_events(select=["25 <= network-matched-filter-snr <= 30"])
#this is equivalent to
#query_events(select=["network-matched-filter-snr <= 30", "network-matched-filter-snr>= 25"])
print(selection)
# Out:
# ['GW240105_151143-v1', 'GW230627_015337-v1', 'GW200129_065458-v1', 'GW190814-v1', 'GW190814_211039-v3', 'GW190521_074359-v2', 'GW150914-v3', 'GW150914-v4']

# %% [markdown]
# Note that this module will give the list of **all available versions** for all the events that have the required parameters. For example, in this query the event GW190814 is listed twice because 2 versions of that event satisfy the request of SNR between 25 and 30.

# %% [markdown]
# ## Quiz Questions

# %% [markdown]
# Now that you've seen examples of how to query for dataset information using the `gwosc` package, please try and complete the following exercises using that interface and enter your response on Thinkific.

# %% [markdown]
# ### Question 1 (no code needed, reply on Thinkific)

# %% [markdown]
# What can be accessed from the Gravitational Wave Open Science Center?

# %% [markdown]
# **<font color="red">Solutions</font>**
#
# One can find the different **catalogs** of gravitational-wave transients. We can also find the **events** within each catalogs, or within some given time range, or those that fulfill certain criteria (e.g. SNR threshold). Finally, we can also locate the public **data**.

# %% [markdown]
# ### Question 2

# %% [markdown]
# How many months did O2 last?

# %%
#-- To answer this, we need to use the `run_segment` function to get the start time and end time of O2.
#-- `run_segment` returns a tuple () that contains two elements. We assign the output (i.e. the tuple) to a variable o2_time_range.
o2_time_range = run_segment('O2')

#-- Now, o2_time_range is a tuple with two elements, which we can call with o2_time_range[0] and o2_time_range[1].
#-- They represent the **start time** and **end time** of O2 respectively.
print("The start time of O2 is %s." % o2_time_range[0])
print("The end time of O2 is %s." % o2_time_range[1])

#-- Finally, we simply need to subtract the start time from the end time to get the time (in second) lasted in O2.
#-- To convert it to months, we divide it by (roughly) 30 days ~ 30 * 24 * 60 * 60
#-- We further use round(_,2) to round the answer to 2 decimal places.
time_in_seconds = o2_time_range[1] - o2_time_range[0]
time_in_months = time_in_seconds / (60.0 * 60.0 * 24.0 * 30.0)
print("O2 lasted for %s months." % round(time_in_months,2))

print("\n")

## Advanced python user can finish this in fewer lines:
print("--Alternative solutions--")
start, end = run_segment('O2')
time_in_months = (end - start) / 60./ 60. / 24. / 30.
print("O2 lasted for %s months." % round(time_in_months,2))
# Out:
# The start time of O2 is 1164556817.
# The end time of O2 is 1187733618.
# O2 lasted for 8.94 months.
#
#
# --Alternative solutions--
# O2 lasted for 8.94 months.

# %% [markdown]
# ### Question 3

# %% [markdown]
# How many GWTC-3-confident events were detected during O3b?

# %%
#-- To answer this, we first need to figure out the **segment** of O3b using `run_segment`
o3b_time_range = run_segment('O3b')

#-- The corresponding catalog we need to search for is `GWTC-3-confident`. Here, we use
#-- datasets.find_datasets to find the list of events in that catalog **AND** within O3b
#-- We need to specify the type as `events`, `catalog` as `GWTC-3-confident`, and
#-- `segment` as `o3b_time_range` (the tuple)
#-- The function will return a **list** of all the events.
#-- For illustrative purposes, we print the list of events as well.
o3b_events = datasets.find_datasets(  type='events',
                                      catalog='GWTC-3-confident',
                                      segment=o3b_time_range)

print("Below shows the list of GWTC-3-confident events in O3b:")
print(o3b_events)

#-- The number of events is simply the **length** of the list. We can use `len`
#-- to obtain the answer.
num_events = len(o3b_events)
print("Number of GWTC-3-confident events in O3b is %s.\n" % num_events)

## Advanced python user can finish this in fewer lines:
print("--Alternative solutions--")
o3b_events = datasets.find_datasets(  type='events',
                                      catalog='GWTC-3-confident',
                                      segment=run_segment('O3b'))
print("Number of GWTC-3-confident events in O3b is %s.\n" % len(o3b_events))
# Out:
# Below shows the list of GWTC-3-confident events in O3b:
# ['GW191103_012549-v1', 'GW191105_143521-v1', 'GW191109_010717-v1', 'GW191113_071753-v1', 'GW191126_115259-v1', 'GW191127_050227-v1', 'GW191129_134029-v1', 'GW191204_110529-v1', 'GW191204_171526-v1', 'GW191215_223052-v1', 'GW191216_213338-v1', 'GW191219_163120-v1', 'GW191222_033537-v1', 'GW191230_180458-v1', 'GW200112_155838-v1', 'GW200115_042309-v2', 'GW200128_022011-v1', 'GW200129_065458-v1', 'GW200202_154313-v1', 'GW200208_130117-v1', 'GW200208_222617-v1', 'GW200209_085452-v1', 'GW200210_092254-v1', 'GW200216_220804-v1', 'GW200219_094415-v1', 'GW200220_061928-v1', 'GW200220_124850-v1', 'GW200224_222234-v1', 'GW200225_060421-v1', 'GW200302_015811-v1', 'GW200306_093714-v1', 'GW200308_173609-v1', 'GW200311_115853-v1', 'GW200316_215756-v1', 'GW200322_091133-v1']
# Number of GWTC-3-confident events in O3b is 35.
#
# --Alternative solutions--
# Number of GWTC-3-confident events in O3b is 35.

# %% [markdown]
# ### Question 4

# %% [markdown]
# How many events have been detected with a network signal to noise ratio (SNR) >= 30? Hint: pay attention to the events' name.

# %%
#-- This seems to be a simple problem. We simply need to use `query_events` with
#-- the contraint being `network-matched-filter-snr >= 30` to get the list of events.

list_of_events = query_events(select=['network-matched-filter-snr >= 30'])
print(list_of_events)

#-- However, if you look closely to the event list, two of the events are actually
#-- the same (degenerate, identical, whichever way you want to say it). In fact,
#-- they are the same event, but they represent **different versions** of the event
#-- coming from earlier and later, detailed analyses. Therefore, considering that
#-- fact as well, the actual number of events is just **3**

print("The number of events with SNR >= 30 is %s.\n" % 3)

#-- For advanced python users, you may notice that each element (event) is formatted
#-- in {event_id}-{version}. Therefore, one can in principle reduces the list to
#-- only contain the event ids, then trim down the list to hold only **unique**
#-- events.
print("--Alternative solutions--")
list_of_events = query_events(select=['network-matched-filter-snr >= 30'])

#- For every event in the list, we use `.split` to split the string into a list,
#- with `-` as the delimiter. Then we take the first part [0], corresponding to
#- the event_id, and store them in the list
list_of_events = [event.split('-')[0] for event in list_of_events]

print("Reduced list: %s" % list_of_events)

#- We can then use `set` to trim down the list to hold only unique elements.
#- Finally, we need to format the output as a `list` again.
list_of_events = list(set(list_of_events))
print("Trimmed list: %s" % list_of_events)

#- Now we can answer without hard-coding
print("The number of events with SNR >= 30 is %s.\n" % len(list_of_events))
# Out:
# ['GW231226_101520-v1', 'GW230814_230901-v1', 'GW230814_230901-v2', 'GW170817-v3']
# The number of events with SNR >= 30 is 3.
#
# --Alternative solutions--
# Reduced list: ['GW231226_101520', 'GW230814_230901', 'GW230814_230901', 'GW170817']
# Trimmed list: ['GW170817', 'GW230814_230901', 'GW231226_101520']
# The number of events with SNR >= 30 is 3.
